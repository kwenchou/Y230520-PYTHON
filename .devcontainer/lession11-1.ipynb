# %%
import requests
import pandas as pd
import streamlit as st

#下載youbike資料
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
response = requests.request('GET',url)
if response.status_code == 200:
    print("連線成功")
    all_data = response.json()
    print(type(all_data))
else:
    print(f"連線失敗:{response.status_code}")
# Out:
# 連線成功
# <class 'list'>

# %%
#將youbike資料轉成dataFrame
dataFrame = pd.DataFrame(data=all_data,columns=['sna','tot','sbi','sarea','mday','ar','bemp','act'])
dataFrame
# Out:
#                            sna  tot  sbi   sarea                 mday
# 0           YouBike2.0_捷運科技大樓站   28    9     大安區  2023-06-10 13:39:14  \
# 1       YouBike2.0_復興南路二段273號前   21    7     大安區  2023-06-10 13:24:13
# 2         YouBike2.0_國北教大實小東側門   16    4     大安區  2023-06-10 13:23:14
# 3            YouBike2.0_和平公園東側   11    6     大安區  2023-06-10 13:34:14
# 4         YouBike2.0_辛亥復興路口西北側   16   10     大安區  2023-06-10 13:30:39
# ...                        ...  ...  ...     ...                  ...
# 1276      YouBike2.0_臺大總圖書館西南側   30   16    臺大專區  2023-06-10 13:03:15
# 1277        YouBike2.0_臺大黑森林西側   20    3    臺大專區  2023-06-10 13:38:14
# 1278        YouBike2.0_臺大獸醫館南側   24    2    臺大專區  2023-06-10 13:35:04
# 1279      YouBike2.0_臺大新體育館東南側   40   13    臺大專區  2023-06-10 13:39:14
# 1280  YouBike2.0_臺大明達館北側(員工宿舍)   18    1  臺大公館校區  2023-06-10 12:06:04
#
#                  ar  bemp act
# 0       復興南路二段235號前    19   1
# 1      復興南路二段273號西側    14   1
# 2       和平東路二段96巷7號    12   1
# 3     和平東路二段118巷33號     5   1
# 4        復興南路二段368號     6   1
# ...             ...   ...  ..
# 1276       臺大圖書館西南側    14   1
# 1277        臺大霖澤館南側    17   1
# 1278       臺大獸醫系館南側    22   1
# 1279        臺大體育館東側    17   1
# 1280       明達館北側前空地    17   1
#
# [1281 rows x 8 columns]

# %%
option = st.selectbox('行政區域',areas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 option = st.selectbox('行政區域',areas)
#
# NameError: name 'areas' is not defined
